# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as ms
import librosa.display
ms.use('seaborn-muted')
# %matplotlib inline
import IPython.display as ipd
import librosa
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8040\949751775.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   ms.use('seaborn-muted')

# %%
data,sr=librosa.load('Music.mp3')

# %%
print(data.shape)
# Out:
# (13075712,)

# %%
S = librosa.feature.melspectrogram(y=data,sr=sr)
log_S = librosa.power_to_db(S,ref = np.max)

# %%
plt.plot(log_S)
plt.show()

# %%
chromagram = librosa.feature.chroma_stft(y=data,sr=sr)
plt.figure(figsize=(15,5))
librosa.display.specshow(chromagram,x_axis='time',y_axis='chroma')

# %%
onset_env=librosa.onset.onset_strength(y=data,sr=sr)

# %%
tempo = librosa.beat.tempo(onset_envelope=onset_env, sr=sr)
print(tempo)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8040\1933835141.py:1: FutureWarning: librosa.beat.tempo
# 	This function was moved to 'librosa.feature.rhythm.tempo' in librosa version 0.10.0.
# 	This alias will be removed in librosa version 1.0.
#   tempo = librosa.beat.tempo(onset_envelope=onset_env, sr=sr)
# [123.046875]

# %%
y_harmonic,y_percussive = librosa.effects.hpss(data)
tempo, beats = librosa.beat.beat_track(y = y_percussive,sr=sr)

# %%
tempo
# Out:
# 143.5546875

# %%
beats
# Out:
# array([   49,    66,    86, ..., 25240, 25258, 25275])
